# %%
# %matplotlib notebook

# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
import pandas as pd

# %%
wage_data = pd.read_csv (r'C:\Users\16787\Desktop\Project1\Wage_Distribution.csv')
wage_data
# Out:
#      ID Wage Bin   Wage Bin  Year  Total Population  \
# 0             21     $200k+  2018            111999
# 1             20  $190-200k  2018              9600
# 2             19  $180-190k  2018             13955
# 3             18  $170-180k  2018             17841
# 4             17  $160-170k  2018             21063
# ..           ...        ...   ...               ...
# 100           20  $190-200k  2014              4866
# 101            6    $50-60k  2014            329699
# 102           21     $200k+  2014             77804
# 103           13  $120-130k  2014             48318
# 104            1     < $10K  2014            591714
#
#      Total Population MOE Appx Geography ID Geography
# 0                  8118.879971   Georgia    04000US13
# 1                  2403.093686   Georgia    04000US13
# 2                  2896.011331   Georgia    04000US13
# 3                  3273.154757   Georgia    04000US13
# 4                  3555.240906   Georgia    04000US13
# ...

# %%
wage_range = wage_data[["Year", "Wage Bin", "Total Population"]]
wage_range = wage_range.set_index("Wage Bin")
wage_range.head()
# Out:
#            Year  Total Population
# Wage Bin
# $200k+     2018            111999
# $190-200k  2018              9600
# $180-190k  2018             13955
# $170-180k  2018             17841
# $160-170k  2018             21063

# %%
wage_range = wage_data.groupby("Year")
count_wages = wage_range["Wage Bin"].count()
count_wages
# Out:
# Year
# 2014    21
# 2015    21
# 2016    21
# 2017    21
# 2018    21
# Name: Wage Bin, dtype: int64

# %%
count

# %%
mplot = wage_range.plot(kind="bar", figsize=(20,6))
multi_plot.set_xticklabels(wage_range["Wage Bin"], rotation=45 )
plt.show()
plt.tight_layout
# Out:
# <img src="data:image/png;base64,..." width="2000">
# <img src="data:image/png;base64,..." width="2000">
# <img src="data:image/png;base64,..." width="2000">
# <img src="data:image/png;base64,..." width="2000">
# <img src="data:image/png;base64,..." width="2000">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-18c7a212240a> in <module>
#       1 multi_plot = wage_range.plot(kind="bar", figsize=(20,6))
# ----> 2 multi_plot.set_xticklabels(wage_range["Wage Bin"], rotation=45 )
#       3 plt.show()
#       4 plt.tight_layout
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# ...

# %%
multi_plot = wage_range.plot(kind="bar", figuresize=(20,5))
multi_plot.set_xticklabels(wage_data["Wage Bin"], rotation=45 )
plt.show()
plt.tight_layout
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-6ebc2c711a92> in <module>
# ----> 1 multi_plot = wage_range.plot(kind="bar", figuresize=(20,5))
#       2 multi_plot.set_xticklabels(wage_data["Wage Bin"], rotation=45 )
#       3 plt.show()
#       4 plt.tight_layout
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
years = [2013, 2014, 2015, 2016, 2017, 2018]
wage = ["<40k", "80k", "100k", "140k", "180k", "200k+"]
