# %%
import requests
import json
import numpy as np
from pprint import pprint
from config import api_key
import csv
import matplotlib.pyplot as plt
import pandas as pd
import http.client

# %%
median_data = pd.read_csv (r'C:\Users\16787\Desktop\Project1\Median_Household_Income1.csv')
median_data
# Out:
#    ID Year  Year  Household Income by Race  Household Income by Race Moe  \
# 0     2018  2018                     69464                          1074
# 1     2017  2017                     65381                           760
# 2     2016  2016                     62613                           890
# 3     2015  2015                     60219                           464
# 4     2014  2014                     56166                           741
# 5     2013  2013                     55733                           675
#
#                            Geography  ID Geography  \
# 0  Atlanta-Sandy Springs-Roswell, GA  31000US12060
# 1  Atlanta-Sandy Springs-Roswell, GA  31000US12060
# 2  Atlanta-Sandy Springs-Roswell, GA  31000US12060
# 3  Atlanta-Sandy Springs-Roswell, GA  31000US12060
# 4  Atlanta-Sandy Springs-Roswell, GA  31000US12060
# 5  Atlanta-Sandy Springs-Roswell, GA  31000US12060
#
#                                  Slug Geography
# ...

# %%
year = []
household_income = []
household_race = []
geography = []

# %%
income = [55733, 56166, 60219, 62613, 65381, 69464]
x_axis = np.arange(len(income))

# %%
plt.bar(x_axis, income, color='b', alpha=0.5, align='center')
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["2013", "2014", "2015", "2016", "2017", "2018"])
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.axis.XTick at 0x21b24e01c08>,
# ...
#  <a list of 6 Text xticklabel objects>)

# %%
plt.xlim(-0.75, len(x_axis)-0.25)
# Out:
# (-0.75, 5.75)

# %%
plt.title("Median Income Growth in Metro Atlanta")
plt.xlabel("Years")
plt.ylabel("Median Income Range")
# Out:
# Text(25.777777777777786, 0.5, 'Median Income Range')
